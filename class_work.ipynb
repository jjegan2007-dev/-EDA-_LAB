# %% [markdown]
# <a href="https://colab.research.google.com/github/jjegan2007-dev/-EDA-_LAB/blob/main/class_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset = pd.read_csv('dataset_1.csv', encoding='latin1')
print(dataset.head())
# Out:
#    ï»¿EmployeeID    Name  Department  Age Gender  Experience  Salary  \
# 0            101  Ritesh   Marketing   29   Male           0   34149
# 1            102    Riya          HR   28   Male           1   36174
# 2            103  Suresh          HR   35   Male           3   43779
# 3            104  Ritesh          HR   36   Male          14   94654
# 4            105  Sanjay  Operations   43   Male           8   60547
#
#         City
# 0  Hyderabad
# 1  Bangalore
# 2    Kolkata
# 3    Kolkata
# 4  Bangalore

# %%
import pandas as pd
df = pd.read_csv("dataset_1.csv")
print(df.columns)
# Out:
# Index(['EmployeeID', 'Name', 'Department', 'Age', 'Gender', 'Experience',
#        'Salary', 'City'],
#       dtype='object')

# %%
import pandas as pd
df = pd.read_csv("dataset_1.csv")
print(df.dtypes)
# Out:
# EmployeeID     int64
# Name          object
# Department    object
# Age            int64
# Gender        object
# Experience     int64
# Salary         int64
# City          object
# dtype: object

# %%
import pandas as pd
df = pd.read_csv("dataset_1.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  500 non-null    int64
#  1   Name        500 non-null    object
#  2   Department  500 non-null    object
#  3   Age         500 non-null    int64
#  4   Gender      500 non-null    object
#  5   Experience  500 non-null    int64
#  6   Salary      500 non-null    int64
#  7   City        500 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 31.4+ KB
# None

# %%
import pandas as pd
df = pd.read_csv("dataset_1.csv")
print(df.describe())
# Out:
#        EmployeeID         Age  Experience        Salary
# count  500.000000  500.000000  500.000000     500.00000
# mean   350.500000   40.678000    9.724000   73043.70600
# std    144.481833   11.213108    8.928564   40302.51262
# min    101.000000   22.000000    0.000000   25000.00000
# 25%    225.750000   30.000000    2.750000   40954.75000
# 50%    350.500000   41.000000    7.000000   58837.50000
# 75%    475.250000   50.000000   15.000000   98947.50000
# max    600.000000   60.000000   37.000000  195854.00000

# %%
import pandas as pd
df = pd.read_csv("dataset_1.csv")
print(print(df.isnull().sum()))
# Out:
# EmployeeID    0
# Name          0
# Department    0
# Age           0
# Gender        0
# Experience    0
# Salary        0
# City          0
# dtype: int64
# None

# %%
import pandas as pd
df = pd.read_csv("dataset_1.csv")
missing_percentage = (df.isnull().sum() / len(df)) * 100
print(missing_percentage)
# Out:
# EmployeeID    0.0
# Name          0.0
# Department    0.0
# Age           0.0
# Gender        0.0
# Experience    0.0
# Salary        0.0
# City          0.0
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv("dataset_1.csv")
missing = df.isnull().sum()
print(missing.idxmax())
# Out:
# EmployeeID
