# %% [markdown]
# <a href="https://colab.research.google.com/github/jjegan2007-dev/-EDA-_LAB/blob/main/EDA%20lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df1Rapid = pd.DataFrame({ 'PlayerID': [1003, 1007, 1014, 1015, 1016, 1035, 1036, 1040, 1041, 1042, 1044, 1046],
                           'RapidRating': [1700, 2249, 2043, 2033, 2306, 2282, 1770, 1991, 1596, 2121, 1471, 1446] })
df2Rapid = pd.DataFrame({ 'PlayerID': [1053, 1057, 1060, 1061, 1063, 1064, 1065, 1068, 1072, 1077, 1078, 1091, 1092, 1096],
                           'RapidRating': [2086, 1673, 2118, 2359, 2099, 2063, 1473, 2023, 2050, 1575, 1946, 2146, 1650, 1567] })
df1Blitz = pd.DataFrame({ 'PlayerID': [1002, 1007, 1009, 1014, 1015, 1016, 1028, 1035, 1036, 1038, 1040, 1046, 1047],
                           'BlitzRating': [1898, 1485, 1782, 1994, 1785, 2372, 2160, 2289, 1642, 1892, 1635, 1855, 1888] })

df2Blitz = pd.DataFrame({ 'PlayerID': [1051, 1053, 1057, 1065, 1068, 1078, 1079, 1085, 1088, 1091, 1095],
                           'BlitzRating': [1663, 1677, 2214, 1480, 2138, 2131, 2308, 2433, 1864, 1373, 1584] })
dfRapid = pd.concat([df1Rapid, df2Rapid])
print(dfRapid)
# Out:
#     PlayerID  RapidRating
# 0       1003         1700
# 1       1007         2249
# 2       1014         2043
# 3       1015         2033
# 4       1016         2306
# 5       1035         2282
# 6       1036         1770
# 7       1040         1991
# 8       1041         1596
# 9       1042         2121
# 10      1044         1471
# 11      1046         1446
# 0       1053         2086
# 1       1057         1673
# 2       1060         2118
# 3       1061         2359
# 4       1063         2099
# 5       1064         2063
# 6       1065         1473
# 7       1068         2023
# 8       1072         2050
# 9       1077         1575
# 10      1078         1946
# 11      1091         2146
# 12      1092         1650
# 13      1096         1567

# %%
import pandas as pd
df1Rapid = pd.DataFrame({ 'PlayerID': [1003, 1007, 1014, 1015, 1016, 1035, 1036, 1040, 1041, 1042, 1044, 1046],
                           'RapidRating': [1700, 2249, 2043, 2033, 2306, 2282, 1770, 1991, 1596, 2121, 1471, 1446] })
df2Rapid = pd.DataFrame({ 'PlayerID': [1053, 1057, 1060, 1061, 1063, 1064, 1065, 1068, 1072, 1077, 1078, 1091, 1092, 1096],
                           'RapidRating': [2086, 1673, 2118, 2359, 2099, 2063, 1473, 2023, 2050, 1575, 1946, 2146, 1650, 1567] })
df1Blitz = pd.DataFrame({ 'PlayerID': [1002, 1007, 1009, 1014, 1015, 1016, 1028, 1035, 1036, 1038, 1040, 1046, 1047],
                           'BlitzRating': [1898, 1485, 1782, 1994, 1785, 2372, 2160, 2289, 1642, 1892, 1635, 1855, 1888] })

df2Blitz = pd.DataFrame({ 'PlayerID': [1051, 1053, 1057, 1065, 1068, 1078, 1079, 1085, 1088, 1091, 1095],
                           'BlitzRating': [1663, 1677, 2214, 1480, 2138, 2131, 2308, 2433, 1864, 1373, 1584] })
dfRapid = pd.concat([df1Rapid, df2Rapid],ignore_index = True)
print(dfRapid)
# Out:
#     PlayerID  RapidRating
# 0       1003         1700
# 1       1007         2249
# 2       1014         2043
# 3       1015         2033
# 4       1016         2306
# 5       1035         2282
# 6       1036         1770
# 7       1040         1991
# 8       1041         1596
# 9       1042         2121
# 10      1044         1471
# 11      1046         1446
# 12      1053         2086
# 13      1057         1673
# 14      1060         2118
# 15      1061         2359
# 16      1063         2099
# 17      1064         2063
# 18      1065         1473
# 19      1068         2023
# 20      1072         2050
# 21      1077         1575
# 22      1078         1946
# 23      1091         2146
# 24      1092         1650
# 25      1096         1567

# %%
import pandas as pd
df1Rapid = pd.DataFrame({ 'PlayerID': [1003, 1007, 1014, 1015, 1016, 1035, 1036, 1040, 1041, 1042, 1044, 1046],
                           'RapidRating': [1700, 2249, 2043, 2033, 2306, 2282, 1770, 1991, 1596, 2121, 1471, 1446] })
df2Rapid = pd.DataFrame({ 'PlayerID': [1053, 1057, 1060, 1061, 1063, 1064, 1065, 1068, 1072, 1077, 1078, 1091, 1092, 1096],
                           'RapidRating': [2086, 1673, 2118, 2359, 2099, 2063, 1473, 2023, 2050, 1575, 1946, 2146, 1650, 1567] })
df1Blitz = pd.DataFrame({ 'PlayerID': [1002, 1007, 1009, 1014, 1015, 1016, 1028, 1035, 1036, 1038, 1040, 1046, 1047],
                           'BlitzRating': [1898, 1485, 1782, 1994, 1785, 2372, 2160, 2289, 1642, 1892, 1635, 1855, 1888] })

df2Blitz = pd.DataFrame({ 'PlayerID': [1051, 1053, 1057, 1065, 1068, 1078, 1079, 1085, 1088, 1091, 1095],
                           'BlitzRating': [1663, 1677, 2214, 1480, 2138, 2131, 2308, 2433, 1864, 1373, 1584] })

dfBlitz = pd.concat([df1Blitz, df2Blitz],ignore_index=True)
print(dfBlitz)
# Out:
#     PlayerID  BlitzRating
# 0       1002         1898
# 1       1007         1485
# 2       1009         1782
# 3       1014         1994
# 4       1015         1785
# 5       1016         2372
# 6       1028         2160
# 7       1035         2289
# 8       1036         1642
# 9       1038         1892
# 10      1040         1635
# 11      1046         1855
# 12      1047         1888
# 13      1051         1663
# 14      1053         1677
# 15      1057         2214
# 16      1065         1480
# 17      1068         2138
# 18      1078         2131
# 19      1079         2308
# 20      1085         2433
# 21      1088         1864
# 22      1091         1373
# 23      1095         1584

# %%
dfR = pd.concat([df1Rapid,df2Rapid], axis=1)
print(df)
# Out:
#     PlayerID  RapidRating  PlayerID  RapidRating
# 0     1003.0       1700.0      1053         2086
# 1     1007.0       2249.0      1057         1673
# 2     1014.0       2043.0      1060         2118
# 3     1015.0       2033.0      1061         2359
# 4     1016.0       2306.0      1063         2099
# 5     1035.0       2282.0      1064         2063
# 6     1036.0       1770.0      1065         1473
# 7     1040.0       1991.0      1068         2023
# 8     1041.0       1596.0      1072         2050
# 9     1042.0       2121.0      1077         1575
# 10    1044.0       1471.0      1078         1946
# 11    1046.0       1446.0      1091         2146
# 12       NaN          NaN      1092         1650
# 13       NaN          NaN      1096         1567

# %%
dfB = pd.concat([df1Blitz,df2Blitz], axis=1)
print(df)
# Out:
#     PlayerID  BlitzRating  PlayerID  BlitzRating
# 0       1002         1898    1051.0       1663.0
# 1       1007         1485    1053.0       1677.0
# 2       1009         1782    1057.0       2214.0
# 3       1014         1994    1065.0       1480.0
# 4       1015         1785    1068.0       2138.0
# 5       1016         2372    1078.0       2131.0
# 6       1028         2160    1079.0       2308.0
# 7       1035         2289    1085.0       2433.0
# 8       1036         1642    1088.0       1864.0
# 9       1038         1892    1091.0       1373.0
# 10      1040         1635    1095.0       1584.0
# 11      1046         1855       NaN          NaN
# 12      1047         1888       NaN          NaN

# %%
df = dfRapid.merge(dfBlitz, how='left')
print(df)
# Out:
#     PlayerID  RapidRating  BlitzRating
# 0       1003         1700          NaN
# 1       1007         2249       1485.0
# 2       1014         2043       1994.0
# 3       1015         2033       1785.0
# 4       1016         2306       2372.0
# 5       1035         2282       2289.0
# 6       1036         1770       1642.0
# 7       1040         1991       1635.0
# 8       1041         1596          NaN
# 9       1042         2121          NaN
# 10      1044         1471          NaN
# 11      1046         1446       1855.0
# 12      1053         2086       1677.0
# 13      1057         1673       2214.0
# 14      1060         2118          NaN
# 15      1061         2359          NaN
# 16      1063         2099          NaN
# 17      1064         2063          NaN
# 18      1065         1473       1480.0
# 19      1068         2023       2138.0
# 20      1072         2050          NaN
# 21      1077         1575          NaN
# 22      1078         1946       2131.0
# ...

# %%
df = dfRapid.merge(dfBlitz, how='right')
print(df)
# Out:
#     PlayerID  RapidRating  BlitzRating
# 0       1002          NaN         1898
# 1       1007       2249.0         1485
# 2       1009          NaN         1782
# 3       1014       2043.0         1994
# 4       1015       2033.0         1785
# 5       1016       2306.0         2372
# 6       1028          NaN         2160
# 7       1035       2282.0         2289
# 8       1036       1770.0         1642
# 9       1038          NaN         1892
# 10      1040       1991.0         1635
# 11      1046       1446.0         1855
# 12      1047          NaN         1888
# 13      1051          NaN         1663
# 14      1053       2086.0         1677
# 15      1057       1673.0         2214
# 16      1065       1473.0         1480
# 17      1068       2023.0         2138
# 18      1078       1946.0         2131
# 19      1079          NaN         2308
# 20      1085          NaN         2433
# 21      1088          NaN         1864
# 22      1091       2146.0         1373
# ...
