# %% [markdown]
# <a href="https://colab.research.google.com/github/jjegan2007-dev/-EDA-_LAB/blob/main/EXP1_07.07.2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("JEGAN/n25BDS0282")

n = int(input("Enter the number: "))
sum = 0

for i in range(1, n + 1):
    sum += i

print("The sum of first n natural numbers is:", sum)
# Out:
# JEGAN/n25BDS0282
# Enter the number: 5
# The sum of first n natural numbers is: 15

# %%
print("JEGAN/n25BDS0282")

s = input("Enter the string: ")
x = s[::-1]

if s == x:
    print("The given string is a palindrome")
else:
    print("The given string is not a palindrome")
# Out:
# JEGAN/n25BDS0282
# Enter the string: bob
# The given string is a palindrome

# %%
print("JEGAN/n25BDS0282")

n = int(input("Enter the number: "))

if n % 2 == 0:
    print("The given number is even")
else:
    print("The given number is odd")
# Out:
# JEGAN/n25BDS0282
# Enter the number: 10
# The given number is even

# %%
print("JEGAN/n25BDS0282")

s = input("Enter the string to be reversed: ")
print(s[::-1])
# Out:
# JEGAN/n25BDS0282
# Enter the string to be reversed: jegan
# nagej

# %%
print("JEGAN/n25BDS0282")

s = input("Enter the string: ")

freq = {}

for i in s:
    freq[i] = freq.get(i, 0) + 1

print(freq)
# Out:
# JEGAN/n25BDS0282
# Enter the string: hello
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %%
print("JEGAN/n25BDS0282")

n = int(input("Enter the number: "))
factors = []

for i in range(1, n + 1):
    if n % i == 0:
        factors.append(i)

print("The factors of n are:", factors)
# Out:
# JEGAN/n25BDS0282
# Enter the number: 25
# The factors of n are: [1, 5, 25]

# %%
print("JEGAN/n25BDS0282")

list1 = [12, 3, 5, 7, 6]
print(list1)

flag = False

target = int(input("Enter the target element: "))

for i in range(len(list1)):
    if target == list1[i]:
        print("The element is found at index:", i)
        flag = True
        break

if flag == False:
    print("The element is not found")
# Out:
# JEGAN/n25BDS0282
# [12, 3, 5, 7, 6]
# Enter the target element: 5
# The element is found at index: 2

# %%
print("JEGAN/n25BDS0282")

a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))
c = int(input("Enter the third number: "))

if a > b and a > c:
    print("The largest number is:", a)
elif b > a and b > c:
    print("The largest number is:", b)
else:
    print("The largest number is:", c)
# Out:
# JEGAN/n25BDS0282
# Enter the first number: 2
# Enter the second number: 5
# Enter the third number: 9
# The largest number is: 9

# %%
print("JEGAN/n25BDS0282")

list1 = [10, 2, 65, 35, 98, 2, 4]

print("The maximum element is:", max(list1))
# Out:
# JEGAN/n25BDS0282
# The maximum element is: 98

# %%
print("JEGAN/n25BDS0282")

list1 = [10, 2, 65, 35, 98, 2, 4]

l = sorted(list1)

print("The second largest element is:", l[-2])
# Out:
# JEGAN/n25BDS0282
# The second largest element is: 65
