# %% [markdown]
# <a href="https://colab.research.google.com/github/jjegan2007-dev/-EDA-_LAB/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("diabetes.csv")
print(df.head())
print(df.tail())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72             35        0  33.6
# 1          1.0       85             66             29        0  26.6
# 2          8.0      183             64              0        0  23.3
# 3          1.0       89             66             23       94  28.1
# 4          0.0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age Outcome
# 0                     0.627   50       1
# 1                     0.351   31       0
# 2                     0.672   32       1
# 3                     0.167   21       0
# 4                     2.288   33       1
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763         10.0      101             76             48      180  32.9
# 764          2.0      122             70             27        0  36.8
# 765          5.0      121             72             23      112  26.2
# ...

# %%
import pandas as pd
df = pd.read_csv("diabetes.csv")
print(df.shape)
# Out:
# (768, 9)

# %%
import pandas as pd
df = pd.read_csv("diabetes.csv")
print(df.columns )
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
import numpy as np
data = np.genfromtxt('diabetes.csv', delimiter=',', skip_header=1)
print("Shape (Rows, Columns):", data.shape)
print("Dimensions:", data.ndim)
print("Total Elements:", data.size)
print("Data Type:", data.dtype)
# Out:
# Shape (Rows, Columns): (768, 9)
# Dimensions: 2
# Total Elements: 6912
# Data Type: float64

# %%
import numpy as np
data = np.genfromtxt('diabetes.csv', delimiter=',', skip_header=1)
column_means = np.mean(data, axis=0)
print("\nMean values for each feature:\n", column_means)
# Out:
# Mean values for each feature:
#  [         nan 120.89453125  69.10546875  20.53645833  79.79947917
#   31.99257812          nan  33.24088542          nan]

# %%
import numpy as np
data = np.genfromtxt('diabetes.csv', delimiter=',', skip_header=1)
older_patients = data[data[:, 7] > 50]
print("\nNumber of patients older than 50:", older_patients.shape[0])
# Out:
# Number of patients older than 50: 81
