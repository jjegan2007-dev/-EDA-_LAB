# %% [markdown]
# <a href="https://colab.research.google.com/github/jjegan2007-dev/-EDA-_LAB/blob/main/EXP4.1_28.07.2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(df)
# Out:
#    Employee_ID             Name Department  Years_Experience    Salary  \
# 0          101      Alice Smith      Sales               4.0   65000.0
# 1          102        Bob Jones         IT               6.0   82000.0
# 2          103    Charlie Brown         HR               NaN   45000.0
# 3          104     Diana Prince        NaN               2.0   55000.0
# 4          105      Evan Wright         IT               9.0  105000.0
# 5          106  Fiona Gallagher      Sales               1.0       NaN
# 6          107     George Clark  Marketing               5.0   70000.0
# 7          108    Hannah Abbott        NaN               3.0       NaN
# 8          109      Ian Malcolm         IT               NaN   95000.0
# 9          110    Julia Roberts      Sales               8.0   88000.0
#
#    Performance_Score
# 0                8.5
# 1                NaN
# 2                6.2
# 3                7.1
# 4                9.0
# 5                5.5
# 6                NaN
# ...

# %%
import io
import pandas as pd
dataset = """Employee_ID,Name,Department,Years_Experience,Salary,Performance_Score
101,Alice Smith,Sales,4,65000,8.5
102,Bob Jones,IT,6,82000,
103,Charlie Brown,HR,,45000,6.2
104,Diana Prince,,2,55000,7.1
105,Evan Wright,IT,9,105000,9.0
106,Fiona Gallagher,Sales,1,,5.5
107,George Clark,Marketing,5,70000,
108,Hannah Abbott,,3,,6.8
109,Ian Malcolm,IT,,95000,8.2
110,Julia Roberts,Sales,8,88000,7.9"""
df = pd.read_csv(io.StringIO(dataset))
print(df.isnull())
# Out:
#    Employee_ID   Name  Department  Years_Experience  Salary  Performance_Score
# 0        False  False       False             False   False              False
# 1        False  False       False             False   False               True
# 2        False  False       False              True   False              False
# 3        False  False        True             False   False              False
# 4        False  False       False             False   False              False
# 5        False  False       False             False    True              False
# 6        False  False       False             False   False               True
# 7        False  False        True             False    True              False
# 8        False  False       False              True   False              False
# 9        False  False       False             False   False              False

# %%
print(df.notnull())
# Out:
#    Employee_ID  Name  Department  Years_Experience  Salary  Performance_Score
# 0         True  True        True              True    True               True
# 1         True  True        True              True    True              False
# 2         True  True        True             False    True               True
# 3         True  True       False              True    True               True
# 4         True  True        True              True    True               True
# 5         True  True        True              True   False               True
# 6         True  True        True              True    True              False
# 7         True  True       False              True   False               True
# 8         True  True        True             False    True               True
# 9         True  True        True              True    True               True

# %%
print(df.isnull().sum())
# Out:
# Employee_ID          0
# Name                 0
# Department           2
# Years_Experience     2
# Salary               2
# Performance_Score    2
# dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 8

# %%
print(df.count())
# Out:
# Employee_ID          10
# Name                 10
# Department            8
# Years_Experience      8
# Salary                8
# Performance_Score     8
# dtype: int64

# %%
print(df.dropna())
# Out:
#    Employee_ID           Name Department  Years_Experience    Salary  \
# 0          101    Alice Smith      Sales               4.0   65000.0
# 4          105    Evan Wright         IT               9.0  105000.0
# 9          110  Julia Roberts      Sales               8.0   88000.0
#
#    Performance_Score
# 0                8.5
# 4                9.0
# 9                7.9

# %%
print(df.dropna(how ="all"))
# Out:
#    Employee_ID             Name Department  Years_Experience    Salary  \
# 0          101      Alice Smith      Sales               4.0   65000.0
# 1          102        Bob Jones         IT               6.0   82000.0
# 2          103    Charlie Brown         HR               NaN   45000.0
# 3          104     Diana Prince        NaN               2.0   55000.0
# 4          105      Evan Wright         IT               9.0  105000.0
# 5          106  Fiona Gallagher      Sales               1.0       NaN
# 6          107     George Clark  Marketing               5.0   70000.0
# 7          108    Hannah Abbott        NaN               3.0       NaN
# 8          109      Ian Malcolm         IT               NaN   95000.0
# 9          110    Julia Roberts      Sales               8.0   88000.0
#
#    Performance_Score
# 0                8.5
# 1                NaN
# 2                6.2
# 3                7.1
# 4                9.0
# 5                5.5
# 6                NaN
# ...

# %%
print(df.dropna(how = "all",axis = 1))
# Out:
#    Employee_ID             Name Department  Years_Experience    Salary  \
# 0          101      Alice Smith      Sales               4.0   65000.0
# 1          102        Bob Jones         IT               6.0   82000.0
# 2          103    Charlie Brown         HR               NaN   45000.0
# 3          104     Diana Prince        NaN               2.0   55000.0
# 4          105      Evan Wright         IT               9.0  105000.0
# 5          106  Fiona Gallagher      Sales               1.0       NaN
# 6          107     George Clark  Marketing               5.0   70000.0
# 7          108    Hannah Abbott        NaN               3.0       NaN
# 8          109      Ian Malcolm         IT               NaN   95000.0
# 9          110    Julia Roberts      Sales               8.0   88000.0
#
#    Performance_Score
# 0                8.5
# 1                NaN
# 2                6.2
# 3                7.1
# 4                9.0
# 5                5.5
# 6                NaN
# ...

# %%
print(df.dropna(axis=1))
# Out:
#    Employee_ID             Name
# 0          101      Alice Smith
# 1          102        Bob Jones
# 2          103    Charlie Brown
# 3          104     Diana Prince
# 4          105      Evan Wright
# 5          106  Fiona Gallagher
# 6          107     George Clark
# 7          108    Hannah Abbott
# 8          109      Ian Malcolm
# 9          110    Julia Roberts

# %%
import numpy as np
temperature = np.array([22.5, 23.1,22.8, 24.0,21.9, 23.5])
print(pd.Series(temperature))
# Out:
# 0    22.5
# 1    23.1
# 2    22.8
# 3    24.0
# 4    21.9
# 5    23.5
# dtype: float64

# %%
print(temperature.mean())
# Out:
# 22.96666666666667

# %%
print(temperature.sum())
# Out:
# 137.8

# %%
print(temperature.cumsum())
# Out:
# [ 22.5  45.6  68.4  92.4 114.3 137.8]

# %%
import numpy as np
import pandas as pd
temperature = np.array([22.5, 23.1, np.nan, 22.8, 24.0, np.nan, 21.9, 23.5])
zero_df = pd.Series(temperature).fillna(0)
print(zero_df)
# Out:
# 0    22.5
# 1    23.1
# 2     0.0
# 3    22.8
# 4    24.0
# 5     0.0
# 6    21.9
# 7    23.5
# dtype: float64

# %%
import pandas as pd
print(pd.Series(temperature).fillna(method = 'ffill'))
# Out:
# 0    22.5
# 1    23.1
# 2    23.1
# 3    22.8
# 4    24.0
# 5    24.0
# 6    21.9
# 7    23.5
# dtype: float64
# /tmp/ipykernel_1744/1309863734.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(pd.Series(temperature).fillna(method = 'ffill'))

# %%
import pandas as pd
print(pd.Series(temperature).fillna(method = 'bfill'))
# Out:
# 0    22.5
# 1    23.1
# 2    22.8
# 3    22.8
# 4    24.0
# 5    21.9
# 6    21.9
# 7    23.5
# dtype: float64
# /tmp/ipykernel_1744/4232514114.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(pd.Series(temperature).fillna(method = 'bfill'))
